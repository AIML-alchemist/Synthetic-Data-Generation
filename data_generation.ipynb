# %%
import pandas as pd
import random
import string
from faker import Faker
from datetime import datetime, timedelta, date

# %% [markdown]
# ##### Generating fake customer data

# %%
fake = Faker()

def generate_customer_data(num_records, countries=None):
    if countries is None:
        countries = {'en_US': 'United States'}
    
    data = []
    for _ in range(num_records):
        customer_id= fake.unique.random_number(digits=6,fix_len=True)
        birth_date = fake.date_of_birth(minimum_age=18, maximum_age=90).strftime('%Y-%m-%d')
        cusip = fake.random_number(digits=9, fix_len=True)
        duns = fake.random_number(digits=9, fix_len=True)
        ftn = '-'.join([''.join(random.choices(string.digits, k=3)) for _ in range(3)])
        name_first = fake.first_name()
        name_last = fake.last_name()
        name_middle = fake.first_name()
        name_prefix = fake.prefix()
        name_suffix = fake.suffix()
        gender = random.choice(['male', 'female'])
        name_type = random.choice(['corporate', 'individual'])
        ticker = fake.random_element(['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'FB']) if random.choice([True, False]) else None
        email = fake.email()
        employer = fake.company()
        fax = fake.phone_number() if name_type == 'corporate' else None
        phone = fake.phone_number()
        role_id = random.randint(1, 10)  # Assuming role_id is an integer between 1 and 10
        flag_id = random.randint(1, 5)   # Assuming flag_id is an integer between 1 and 5

        locale = random.choice(list(countries.keys()))
        fake.locale = locale
        street_address = fake.street_address()
        city = fake.city()
        state = fake.state_abbr()
        country = countries[locale]
        zip_code = fake.zipcode()
        zip_ext = fake.zipcode_plus4()

        data.append([
           customer_id, birth_date, cusip, duns, ftn, name_first,
            f"{name_first} {name_middle} {name_last}",
            fake.random_element(elements=['Sr.', 'Jr.', 'III', 'IV', 'V']),
            name_last, name_middle, name_prefix, name_suffix, gender, name_type,
            ticker, email, employer, fax, phone,
            role_id, flag_id,
            street_address, city, state, country, zip_code, zip_ext
        ])

    columns = ['customer_id','birth_date', 'cusip', 'duns', 'ftn', 'name_first',
               'full_name', 'name_suffix', 'name_last', 'name_middle', 'name_prefix', 'name_suffix', 'gender',
               'name_type', 'ticker', 'email', 'employer', 'fax', 'phone', 'role_id', 'flag_id',
               'street_address', 'city', 'state', 'country', 'zip_code', 'zip_ext']

    return pd.DataFrame(data, columns=columns)

# %% [markdown]
# ##### Genearting fake account data

# %%
def generate_account_data(num_records):


    data = []
    for _ in range(num_records):
        account_number = fake.unique.random_number(digits=20, fix_len=True)
        bank_id = fake.unique.random_number(digits=6, fix_len=True)
        d_string = '01-01-2024'
        end_dt = pd.to_datetime(d_string)
        account_opened = fake.date_between(start_date='-25y', end_date= end_dt)
        account_status = random.choice(['Active', 'Inactive', 'Purge'])

  

        account_type = fake.random_element(elements=['Savings Account', 'Checking Account', 'Investment Account'])
        account_purpose = fake.sentence(nb_words=6, variable_nb_words=True)
        account_ownership = fake.random_element(elements=['Individual', 'Joint', 'Business Entity'])
        additional_designations = fake.sentence(nb_words=8, variable_nb_words=True)
        if account_ownership == 'Business Entity':
            account_holder_name = fake.company()
        else:
            account_holder_name = fake.name()

        if account_ownership == 'Business Entity':
            certification_status = fake.random_element(elements=['Certified', 'Not Certified', 'Pending'])
            regulatory_certification_status = fake.random_element(elements=['Certified', 'Not Certified', 'Pending'])
            package_id = fake.unique.random_number(digits=5, fix_len=True)
            package_description = fake.catch_phrase()
            business_classification_code = fake.unique.random_number(digits=5, fix_len=True)
            business_classification_description = fake.catch_phrase()
        else:
            certification_status = regulatory_certification_status = package_id = package_description = \
                business_classification_code = business_classification_description = None

        tax_number = fake.random_number(digits=9, fix_len=True)
        tax_type = random.choice(['SSN', 'EIN'])
        risk_id = random.randint(1, 10)  # Assuming risk_id is an integer between 1 and 10

        start_date = account_opened + timedelta(days=30)
        
        if random.choice([True, False]):
            account_close_date = fake.date_between(start_date=start_date, end_date=date.today())
        else:
            account_close_date = None

        data.append([
            account_number, bank_id, account_opened, account_status,
            account_holder_name, account_type, account_purpose,
            account_ownership, additional_designations,
            certification_status, regulatory_certification_status,
            package_id, package_description, tax_number, tax_type, risk_id,
            account_close_date, business_classification_code,
            business_classification_description
        ])

    columns = ['account_number', 'bank_id', 'account_opened', 'account_status',
               'account_holder_name', 'account_type', 'account_purpose',
               'account_ownership', 'additional_designations',
               'certification_status', 'regulatory_certification_status',
               'package_id', 'package_description', 'tax_number', 'tax_type', 'risk_id',
               'account_close_date', 'business_classification_code',
               'business_classification_description']

    return pd.DataFrame(data, columns=columns)

# %% [markdown]
# ##### Generating fake addresses and branch code and assigning to random accounts

# %%
def generate_address_data(num_records, countries=None):
    fake = Faker()
    if countries is None:
        countries = {'en_US': 'United States'}

    street_address = []
    city = []
    state = []
    country = []
    zip_code = []
    zip_ext = []
    branch = []

    for _ in range(num_records):
        locale = random.choice(list(countries.keys()))
        fake.locale = locale

        branch.append(fake.random_number(digits=4, fix_len=True))
        street_address.append(fake.street_address())
        city.append(fake.city())
        state.append(fake.state_abbr())
        country.append(countries[locale])
        zip_code.append(fake.zipcode())
        zip_ext.append(fake.zipcode_plus4())

    address_data = {
        'branch_id': branch,
        'street_address': street_address,
        'city': city,
        'state': state,
        'country': country,
        'zip_code': zip_code,
        'zip_ext': zip_ext
    }

    return pd.DataFrame(address_data)

# If you want to generate addresses with different countries:
# address_df = generate_address_data(1000, countries={'en_US': 'United States', 'en_GB': 'United Kingdom'})

# %%
address_data=generate_address_data(10)
branch_address_data=pd.DataFrame(columns=address_data.columns)
for i in range(1000):
    branch_address_data=pd.concat([branch_address_data,address_data.sample(2)])

# %%
branch_address_data.reset_index(drop=True,inplace=True)

# %%
customer_data=generate_customer_data(1000)

# %%
account_data=generate_account_data(2000)
account_data=pd.concat([account_data,branch_address_data],axis=1)
account_data['customer_id'] = [random.choice(customer_data['customer_id']) for i in range(len(account_data))]

# %%
product_data=pd.read_csv('Data/product.csv')  # import  product.csv 

products=pd.DataFrame({'account_number':random.sample(list(account_data.account_number),k=2000),
                    'product_id':random.choices(product_data.product_id, k=2000),
                      })
print(products)


products=account_data.merge(products,on='account_number',how='inner')
products=products[['customer_id','product_id','account_number']]
products['customer_id']=products['customer_id']
products.drop_duplicates(inplace=True)
# Out:
#             account_number  product_id
# 0     58846836860287965957         562
# 1     93387993470494894639         398
# 2     13698803464290973746         305
# 3     15481214287709978357         196
# 4     56815153848089907912         281
# ...                    ...         ...
# 1995  29780028465301006079         339
# 1996  44977594541331075006         171
# 1997  22494283812647262284         839
# 1998  69334470575789567841         951
# 1999  45891376572578700868         996
#
# [2000 rows x 2 columns]

# %%
product_data
# Out:
#     Unnamed: 0  product_id                                               name  \
# 0            0         867                                      Student Loans
# 1            1         971  Virtual Wallet Checking Pro with Spend, Reserv...
# 2            2         535                                   Customer Service
# 3            3         996                               Investment Solutions
# 4            4         569                            Tax-Efficient Investing
# 5            5         299   PNC Cash UnlimitedSM Visa Signature® Credit Card
# 6            6         767                       Virtual Wallet® Checking Pro
# 7            7          36                                          TurboTax®
# 8            8          15  Send Money to people you know and trust with Z...
# 9            9         959                            PNC High Yield Savings®
# 10          10         861                                    PNC Investments
# 11          11         626                                  Advice & Planning
# 12          12         520                                        PNC HomeHQ®
# 13          13         914                        Retirement Planning Journey
# 14          14         171                       Planning Tools & Calculators
# 15          15         589                         Construction and Lot Loans
# 16          16         133                             Virtual Wallet Student
# 17          17         281                            Online & Mobile Banking
# 18          18         562  Premiere Money Market, Standard Savings, or CD...
# 19          19         924                                      Student Loans
# 20          20         728                          Make Contactless Payments
# 21          21         340                                        Bank Online
# 22          22         610                           Student Loan Refinancing
# 23          23         951                                     Receive Alerts
# 24          24         605             Earn Rewards with PNC Purchase Payback
# 25          25         774                            Tax-Efficient Investing
# 26          26         989                                         Auto Loans
# 27          27         784                        Home Equity Lines of Credit
# 28          28         176                           Student Loan Refinancing
# 29          29         339                   Personal Loans & Lines of Credit
# 30          30         796                                  Advice & Planning
# 31          31         839                                    Make a Transfer
# 32          32         555                                      Check Balance
# 33          33         928              Make Check Deposits into your account
# 34          34         352                        Retirement Planning Journey
# 35          35         162                                         Auto Loans
# 36          36         452                        PNC Core® Visa® Credit Card
# 37          37         550                               Investment Solutions
# 38          38         377                                        PNC HomeHQ®
# 39          39         703                      Mortgage Purchase & Refinance
# 40          40         636                      PNC Secured Visa® Credit Card
# 41          41         659                                          Card Tech
# 42          42         298                   Personal Loans & Lines of Credit
# 43          43         233                                    PNC Investments
# 44          44         851                         Construction and Lot Loans
# 45          45         398                        Home Equity Lines of Credit
# 46          46         168                PNC Cash Rewards® Visa® Credit Card
# 47          47         305                      Mortgage Purchase & Refinance
# 48          48         628                       Planning Tools & Calculators
# 49          49         502                 Lock your cards with PNC Easy Lock
# 50          50         297             Virtual Wallet Checking Pro with Spend
# 51          51         196                      PNC points® Visa® Credit Card
#
#                           category
# 0                             Loan
# 1                         Checking
# 2          Online & Mobile Banking
# 3   Investment and Wealth Planning
# 4   Investment and Wealth Planning
# 5                      Credit Card
# 6     Checking and Savings Account
# 7          Online & Mobile Banking
# 8          Online & Mobile Banking
# 9                  Savings Account
# 10  Investment and Wealth Planning
# 11  Investment and Wealth Planning
# 12                            Loan
# 13  Investment and Wealth Planning
# 14  Investment and Wealth Planning
# 15                            Loan
# 16                        Checking
# 17         Online & Mobile Banking
# 18   Other Savings Account Options
# 19                            Loan
# 20         Online & Mobile Banking
# 21         Online & Mobile Banking
# 22                            Loan
# 23         Online & Mobile Banking
# 24         Online & Mobile Banking
# 25  Investment and Wealth Planning
# 26                            Loan
# 27                            Loan
# 28                            Loan
# 29                            Loan
# 30  Investment and Wealth Planning
# 31         Online & Mobile Banking
# 32         Online & Mobile Banking
# 33         Online & Mobile Banking
# 34  Investment and Wealth Planning
# 35                            Loan
# 36                     Credit Card
# 37  Investment and Wealth Planning
# 38                            Loan
# 39                            Loan
# 40                     Credit Card
# 41         Online & Mobile Banking
# 42                            Loan
# 43  Investment and Wealth Planning
# 44                            Loan
# 45                            Loan
# 46                     Credit Card
# 47                            Loan
# 48  Investment and Wealth Planning
# 49         Online & Mobile Banking
# 50                        Checking
# 51                     Credit Card

# %%
products
# Out:
#       customer_id  product_id        account_number
# 0          874852         520  85823615136333207510
# 1          571374         502  42097252895672518852
# 2          639532         281  82240279093306742028
# 3          739384         928  79281559701093455174
# 4          543594         861  39365005522298388958
# ...           ...         ...                   ...
# 1995       551796         636  13842690391550423401
# 1996       189905         774  37667561898367653093
# 1997       736986         305  80745703155202171593
# 1998       469501         298  38501132325571998048
# 1999       111602         162  81819574932988382142
#
# [2000 rows x 3 columns]

# %%
#saving all files

products.to_csv('Data_new/product_customer.csv',index=False)

account_data.to_csv('Data_new/account.csv',index_label=False,index=False)

customer_data.to_csv('Data_new/customer.csv',index=False)

# %% [markdown]
# ##### Generating data for all other nodes with there connecting links

# %%
# generate_engagement():
engagement=   pd.DataFrame ({
            "engagement_id": [fake.unique.random_number(digits=4,fix_len=True) for i in range(len(product_data))],
            "timestamp": [fake.date_time_this_decade() for i in range(len(product_data))],
            "type_of_engagement": [random.choice(["Phone Call", "Branch Visit", "Online Interaction"]) for i in range(len(product_data))],
            "interaction_details": [fake.sentence() for i in range(len(product_data))],
            "outcome": [random.choice(["Resolved", "Unresolved", "Transaction Completed"]) for i in range(len(product_data))],
            "associated_product": [product_data.iloc[i,1] for i in range(len(product_data))],
            "customer_id" : [product_data.iloc[i,0] for i in range(len(product_data))]
        })


engagement.to_csv("Data_new/engagement.csv", index=False)

# %%
df=engagement[engagement['outcome']=='Unresolved']
df.reset_index(drop=True,inplace=True)
next_engagement=   pd.DataFrame ({
            "engagement_id": [fake.unique.random_number(digits=4,fix_len=True) for i in range(len(df))],
            "timestamp": [fake.date_time_this_decade() for i in range(len(df))],
            "type_of_engagement": [random.choice(["Phone Call", "Branch Visit", "Online Interaction"]) for i in range(len(df))],
            "interaction_details": [fake.sentence() for i in range(len(df))],
            "outcome": [random.choice(["Resolved", "Unresolved", "Transaction Completed"]) for i in range(len(df))],
            "associated_product": [df.loc[i,'associated_product'] for i in range(len(df))],
            "previous_engagement":[df.loc[i,'engagement_id'] for i in range(len(df))]
        })  


next_engagement.to_csv("Data_new/next_engagement.csv", index=False)

# %%
all_engagement=pd.concat([engagement,next_engagement],join='inner',ignore_index=True)
all_engagement.to_csv('Data_new/all_engagement.csv',index=False)

# %%
all_engagement
# Out:
#     engagement_id           timestamp  type_of_engagement  \
# 0            1529 2023-12-19 03:47:11  Online Interaction
# 1            3316 2022-04-20 12:33:23  Online Interaction
# 2            3902 2022-07-29 02:09:45        Branch Visit
# 3            9300 2023-03-27 16:11:59  Online Interaction
# 4            5174 2022-08-08 00:22:54          Phone Call
# ..            ...                 ...                 ...
# 64           5266 2020-03-01 23:06:22        Branch Visit
# 65           5003 2022-06-30 02:11:23          Phone Call
# 66           5720 2021-11-17 23:43:41        Branch Visit
# 67           5532 2023-03-08 17:45:01          Phone Call
# 68           5008 2020-01-31 02:51:16          Phone Call
#
#                                   interaction_details                outcome  \
# 0        Fight show purpose indicate begin shake act.             Unresolved
# 1             Remember serious remember learn though.               Resolved
# 2                       Side method guy feeling safe.               Resolved
# 3      Us mouth general this value national increase.  Transaction Completed
# 4                        Training fact way different.               Resolved
# ..                                                ...                    ...
# 64                       Win soldier first read bank.               Resolved
# 65        Chair cause across kind region might above.             Unresolved
# 66      Professional move put instead affect end law.             Unresolved
# 67  Social future partner town report feeling myself.               Resolved
# 68                             Serve alone among can.  Transaction Completed
#
#     associated_product
# 0                  867
# 1                  971
# 2                  535
# 3                  996
# 4                  569
# ..                 ...
# 64                 784
# 65                 928
# 66                 398
# 67                 168
# 68                 502
#
# [69 rows x 6 columns]

# %%
Channel={"Phone":1, "Email":2, "In-person":3,"Banner":4,"Social-Media":5}

#impression

df=pd.read_csv('Data/product.csv')
impression=pd.DataFrame({
        "impression_id": [fake.unique.random_number(digits=3,fix_len=True) for i in range(52)],
        "timestamp": [fake.date_time_this_decade() for i in range(52)],
        "channel": [random.choice(["Website", "Email", "Social Media"]) for i in range(52)],
        "content": [fake.sentence() for i in range(52)],
        "target_audience": [fake.word() for i in range(52)],
        "response": [random.choice(["Positive", "Negative", "Neutral"]) for i in range(52)],
        "product_id":df.product_id,
        "channel": [random.choice(list(Channel.keys())) for i in range(52)]
})  

impression['channel_id']=[Channel[key] for key in impression['channel']]
impression.to_csv('Data_new/impression.csv',index=False)

# %%
impression
# Out:
#     impression_id           timestamp       channel  \
# 0             786 2020-03-12 07:07:16         Phone
# 1             674 2022-06-26 05:33:06     In-person
# 2             963 2020-07-02 02:21:56  Social-Media
# 3             435 2020-03-05 19:54:19         Phone
# 4             350 2021-06-24 21:28:57         Email
# 5             386 2023-08-14 05:45:38         Email
# 6             978 2021-07-31 12:40:49         Phone
# 7             714 2023-08-16 01:40:00         Email
# 8             262 2020-02-20 02:56:42         Email
# 9             519 2021-05-09 06:37:39        Banner
# 10            247 2021-01-22 03:18:07         Email
# 11            780 2022-06-19 05:43:30         Phone
# 12            973 2023-09-26 10:07:09  Social-Media
# 13            688 2020-10-21 23:29:48        Banner
# 14            732 2021-11-24 10:22:30         Email
# 15            345 2020-04-13 02:42:03         Phone
# 16            983 2020-10-04 08:43:27         Email
# 17            465 2021-03-26 05:52:17         Email
# 18            545 2023-12-01 08:31:55         Email
# 19            250 2022-06-14 09:15:51        Banner
# 20            458 2022-12-05 07:50:44         Phone
# 21            818 2023-12-06 15:38:16         Email
# 22            357 2020-07-14 10:32:09     In-person
# 23            775 2022-07-02 14:54:28  Social-Media
# 24            446 2021-11-27 09:51:49  Social-Media
# 25            111 2023-02-21 00:53:06        Banner
# 26            675 2024-03-06 12:35:04         Phone
# 27            239 2023-06-05 20:09:32         Email
# 28            573 2020-03-22 06:14:06         Email
# 29            783 2022-05-30 09:48:56        Banner
# 30            436 2021-10-10 10:58:51         Email
# 31            203 2021-05-17 12:17:27         Email
# 32            481 2020-02-21 04:51:19  Social-Media
# 33            795 2024-03-23 21:47:41         Email
# 34            800 2023-11-09 23:11:45  Social-Media
# 35            815 2022-06-26 22:08:04     In-person
# 36            201 2024-03-27 22:52:31        Banner
# 37            890 2023-02-19 13:15:24     In-person
# 38            561 2023-09-01 18:10:27         Phone
# 39            657 2023-10-27 21:56:31         Email
# 40            937 2020-03-25 14:15:05        Banner
# 41            707 2021-12-08 07:05:33     In-person
# 42            477 2020-03-31 00:20:34         Email
# 43            229 2023-03-15 01:41:03     In-person
# 44            643 2021-12-24 10:34:45         Phone
# 45            773 2023-02-22 06:04:47         Phone
# 46            382 2024-01-22 15:10:05         Phone
# 47            443 2020-01-10 03:51:41         Email
# 48            670 2023-08-21 18:39:00  Social-Media
# 49            861 2022-02-09 22:01:18        Banner
# 50            474 2020-10-26 06:58:24         Email
# 51            168 2022-12-24 08:08:52  Social-Media
#
#                                               content target_audience  \
# 0          Available address activity evidence hotel.           leave
# 1                                  No go range piece.            fill
# 2            Western affect help city be since catch.       interview
# 3                  Able positive could country piece.         quickly
# 4                                Evening strong deal.            wall
# 5                              Help federal activity.           class
# 6                           Leader address character.              go
# 7                               Building owner thank.        American
# 8         A rest forward program important do or age.            meet
# 9                              Skin spend minute gas.         contain
# 10          Around each nation everything several as.           write
# 11  Democratic girl writer accept find without car...      experience
# 12   Sometimes simply according matter score present.         network
# 13             Item light thousand law although want.          ground
# 14    Value probably these need fish provide tax age.           truth
# 15               Partner song suddenly attorney stop.           often
# 16                  Its popular see perhaps American.             box
# 17                            Democrat turn work any.            pass
# 18                    Administration peace set teach.           hotel
# 19                   What black whole five the range.            know
# 20  Offer professional store leave interesting fol...       determine
# 21                         Music receive leader sign.           eight
# 22                              Line front word them.             oil
# 23  Successful agreement old owner television what...           enjoy
# 24           High price growth wall often wind small.            baby
# 25              Kind great risk along bring standard.         himself
# 26                        Stay itself audience cause.          nation
# 27              Until plant sound so activity future.            time
# 28       Shake who various indicate walk product low.        increase
# 29                                Become finish sell.        building
# 30     Yourself week local run yourself approach age.          parent
# 31               Modern to rather hospital according.        continue
# 32                        Authority program short at.           along
# 33      Good democratic whom white candidate whether.           black
# 34                   Improve produce goal sure occur.              no
# 35                                  One could design.           where
# 36  Democratic human opportunity professor soldier...         product
# 37     Safe authority standard live continue million.           allow
# 38  Something itself well instead major easy impor...            list
# 39                        Trade cover water decision.          design
# 40    Movie manage point market lawyer go production.         believe
# 41          Relationship throughout specific kitchen.        somebody
# 42             Anyone public network box upon do far.         western
# 43                   Phone green half build language.          writer
# 44                           Name guy fast open tree.           woman
# 45                              Film nor sense where.           leave
# 46  Require conference box create I whole four tog...          ground
# 47               Responsibility knowledge deal adult.       including
# 48    Modern beyond difficult staff people follow my.              Mr
# 49  Free several key want floor yet specific strat...          lawyer
# 50                      Wear form rest us our relate.             ago
# 51  Particular would describe on power price candi...            need
#
#     response  product_id  channel_id
# 0   Positive         867           1
# 1    Neutral         971           3
# 2   Positive         535           5
# 3   Positive         996           1
# 4    Neutral         569           2
# 5   Negative         299           2
# 6   Positive         767           1
# 7   Positive          36           2
# 8   Negative          15           2
# 9   Negative         959           4
# 10  Positive         861           2
# 11  Negative         626           1
# 12  Positive         520           5
# 13   Neutral         914           4
# 14  Negative         171           2
# 15  Negative         589           1
# 16  Negative         133           2
# 17   Neutral         281           2
# 18  Positive         562           2
# 19   Neutral         924           4
# 20   Neutral         728           1
# 21  Positive         340           2
# 22  Negative         610           3
# 23   Neutral         951           5
# 24  Positive         605           5
# 25  Negative         774           4
# 26   Neutral         989           1
# 27  Negative         784           2
# 28   Neutral         176           2
# 29  Positive         339           4
# 30  Positive         796           2
# 31  Negative         839           2
# 32   Neutral         555           5
# 33  Negative         928           2
# 34  Negative         352           5
# 35  Negative         162           3
# 36  Negative         452           4
# 37   Neutral         550           3
# 38   Neutral         377           1
# 39  Negative         703           2
# 40   Neutral         636           4
# 41   Neutral         659           3
# 42  Positive         298           2
# 43  Positive         233           3
# 44  Negative         851           1
# 45  Negative         398           1
# 46  Positive         168           1
# 47   Neutral         305           2
# 48  Positive         628           5
# 49  Negative         502           4
# 50  Negative         297           2
# 51   Neutral         196           5

# %%
product_data=products.merge(impression,on='product_id',how='inner')
product_data=product_data[['customer_id','product_id','account_number','impression_id']]

# %%
product_data
# Out:
#       customer_id  product_id        account_number  impression_id
# 0          874852         520  85823615136333207510            973
# 1          940764         520  81530773566307359926            973
# 2          209443         520  97545544052308402351            973
# 3          885532         520  81739716818947702597            973
# 4          637752         520  81580561655080514114            973
# ...           ...         ...                   ...            ...
# 1995       489580         162  84799734366765914183            815
# 1996       620876         162  44194163839245895298            815
# 1997       794248         162  47560543676669014920            815
# 1998       177390         162  99045454581305522136            815
# 1999       111602         162  81819574932988382142            815
#
# [2000 rows x 4 columns]

# %%
#Responce
responce=pd.DataFrame({"response_id": [fake.unique.random_number(digits=4,fix_len=True) for i in range(500)] ,
        "timestamp": [fake.date_time_this_decade() for i in range(500)],
        "response_type": [random.choice(["Positive", "Negative", "Neutral"]) for i in range(500)],
        "content": [fake.sentence() for i in range(500) ]} )
responce['abandoned'] = ["Y" if response_type != 'Positive' else "N" for response_type in responce['response_type']]
responce['impression_id']=[random.choice(list(impression['impression_id'])) for I in range(500)]

responce.to_csv('Data_new/responce.csv',index=False)

# %%
#interaction
interaction = pd.DataFrame({
    "interaction_id": [fake.uuid4() for _ in range(2000)],
    "timestamp": [fake.date_time_this_decade() for _ in range(2000)],
    "type_of_interaction": [random.choice(["Phone Call", "Branch Visit", "Online Chat"]) for _ in range(2000)],
    "interaction_details": [fake.sentence() for _ in range(2000)],
    "outcome": [random.choice(["Inquiry", "Transaction", "Complaint"]) for _ in range(2000)],
    
})


interaction.to_csv('Data_new/interaction.csv',index=False)

# %%
responce
# Out:
#      response_id           timestamp response_type  \
# 0           1725 2022-11-04 04:00:15      Positive
# 1           1892 2022-08-17 03:50:33       Neutral
# 2           4681 2022-03-14 11:06:44      Positive
# 3           7109 2021-01-24 03:48:04       Neutral
# 4           3774 2022-06-20 23:55:19      Positive
# ..           ...                 ...           ...
# 495         2650 2022-12-31 00:52:31      Positive
# 496         9263 2022-12-04 10:37:56      Negative
# 497         3549 2022-09-21 09:48:14       Neutral
# 498         8921 2021-10-10 15:49:44      Positive
# 499         7107 2023-10-02 21:17:32       Neutral
#
#                                               content abandoned  impression_id
# 0                           Where he before positive.         N            262
# 1               Matter standard break resource least.         Y            861
# 2                      Down way economic amount hard.         N            111
# 3                           Nice hot line stand save.         Y            775
# 4                     Certain glass discuss pressure.         N            477
# ..                                                ...       ...            ...
# 495  Scientist as support spend song someone science.         N            818
# 496      Owner professional free none theory company.         Y            973
# 497                            Decade base give most.         Y            707
# 498   Game art recent claim deep recognize sometimes.         N            983
# 499      Charge rather guess perform huge almost big.         Y            435
#
# [500 rows x 6 columns]

# %%
interaction
# Out:
#                             interaction_id           timestamp  \
# 0     ef0a95e6-55b6-4363-887e-3f8fe17af252 2024-02-04 04:27:51
# 1     29d6119d-e08b-4373-875e-2b02309d82bc 2020-08-23 04:20:11
# 2     918e01e7-a3b2-434f-939b-1a8661be860e 2022-09-26 02:03:25
# 3     abb348f6-4c79-44ba-ba7a-e02f829297b8 2021-07-19 09:17:15
# 4     e124da1e-ed00-43d8-94c7-0c449e4f0760 2023-11-05 09:41:51
# ...                                    ...                 ...
# 1995  f6d3b525-1833-4005-9ecf-36cd4025dc17 2021-04-28 08:40:22
# 1996  6b87f4ad-919e-4791-ba90-5bafa719407a 2021-03-31 18:47:26
# 1997  eed56db6-4a98-4f8c-8942-3d76f087869a 2020-02-19 23:02:38
# 1998  e74aec93-8620-4643-a392-c952b83aa0a8 2020-12-30 05:26:56
# 1999  9d873205-4a12-421d-8fc1-714a58e6e824 2023-11-07 15:17:37
#
#      type_of_interaction                                interaction_details  \
# 0             Phone Call         Fact boy behavior produce wind skill loss.
# 1            Online Chat                   Two size old hit mean scientist.
# 2             Phone Call                             Physical middle right.
# 3           Branch Visit                                    Appear do goal.
# 4           Branch Visit               Value those pay property avoid born.
# ...                  ...                                                ...
# 1995          Phone Call                             Town impact true main.
# 1996        Branch Visit               Ever chance establish central style.
# 1997        Branch Visit             Usually Mr page more opportunity plan.
# 1998          Phone Call                              Audience direction I.
# 1999          Phone Call  Risk pretty activity red become break capital ...
#
#           outcome
# 0       Complaint
# 1     Transaction
# 2     Transaction
# 3       Complaint
# 4         Inquiry
# ...           ...
# 1995    Complaint
# 1996  Transaction
# 1997      Inquiry
# 1998  Transaction
# 1999  Transaction
#
# [2000 rows x 5 columns]

# %%
product_data['interaction_id']=interaction['interaction_id']    #linking iteractions to product and customer data
product_data.to_csv('Data_new/product_customer_impression.csv',index=False)

# %%
product_data
# Out:
#       customer_id  product_id        account_number  impression_id  \
# 0          874852         520  85823615136333207510            973
# 1          940764         520  81530773566307359926            973
# 2          209443         520  97545544052308402351            973
# 3          885532         520  81739716818947702597            973
# 4          637752         520  81580561655080514114            973
# ...           ...         ...                   ...            ...
# 1995       489580         162  84799734366765914183            815
# 1996       620876         162  44194163839245895298            815
# 1997       794248         162  47560543676669014920            815
# 1998       177390         162  99045454581305522136            815
# 1999       111602         162  81819574932988382142            815
#
#                             interaction_id
# 0     ef0a95e6-55b6-4363-887e-3f8fe17af252
# 1     29d6119d-e08b-4373-875e-2b02309d82bc
# 2     918e01e7-a3b2-434f-939b-1a8661be860e
# 3     abb348f6-4c79-44ba-ba7a-e02f829297b8
# 4     e124da1e-ed00-43d8-94c7-0c449e4f0760
# ...                                    ...
# 1995  f6d3b525-1833-4005-9ecf-36cd4025dc17
# 1996  6b87f4ad-919e-4791-ba90-5bafa719407a
# 1997  eed56db6-4a98-4f8c-8942-3d76f087869a
# 1998  e74aec93-8620-4643-a392-c952b83aa0a8
# 1999  9d873205-4a12-421d-8fc1-714a58e6e824
#
# [2000 rows x 5 columns]

# %%
df = interaction[interaction['outcome'].isin(['Inquiry', 'Complaint'])]
df.reset_index(drop=True,inplace=True)
merged_data = pd.merge(product_data, df, on='interaction_id', how='inner')
interaction_level2 = pd.DataFrame({
    "interaction_id": [fake.uuid4() for _ in range(len(df))],
    "timestamp": [fake.date_time_this_decade()  for _ in range(len(df))],
    "type_of_interaction": [random.choice(["Phone Call", "Branch Visit", "Online Chat"])  for _ in range(len(df))],
    "interaction_details": [fake.sentence()  for _ in range(len(df))],
    "outcome": [random.choice(["Inquiry", "Transaction", "Complaint"])  for _ in range(len(df))],
    "customer_id": merged_data['customer_id'],
    "previous_interaction": merged_data['interaction_id']
})


interaction_level2.to_csv('Data_new/interaction_level2.csv',index=False)

# %%
interaction_level2
# Out:
#                             interaction_id           timestamp  \
# 0     c7c25ca1-3334-4980-9385-51b1761af7a0 2023-03-20 20:25:49
# 1     793e0053-4f4c-4a7f-b875-492856a08300 2020-01-26 01:49:59
# 2     fdbbf69d-9f01-4285-b5f7-b031b4bbdcd0 2020-04-19 18:59:44
# 3     0987d6b2-b32e-418e-b6d2-03785929d393 2020-10-23 12:20:42
# 4     d29fc9ed-6a33-44df-8d39-3c0345573dd0 2024-01-10 15:02:59
# ...                                    ...                 ...
# 1310  adc0fdfe-8b31-476c-bc41-ddc951a009a2 2022-03-15 17:09:02
# 1311  4f061966-ef23-46da-90d3-33e13bac3fb1 2021-07-31 12:38:52
# 1312  a94c405b-34bc-447d-bec0-538380c28302 2023-12-25 17:56:33
# 1313  57e9891c-5434-4d5a-afb1-474d3f527343 2020-02-06 04:22:14
# 1314  26c0193f-8566-48ed-915e-5f9c72bc0d88 2020-02-10 17:38:25
#
#      type_of_interaction                              interaction_details  \
# 0             Phone Call       Day total minute industry role individual.
# 1            Online Chat   Father increase term once recently lay spring.
# 2             Phone Call         Commercial seat recognize picture ahead.
# 3            Online Chat             Mean past join suggest nature focus.
# 4            Online Chat                 Long dream amount church social.
# ...                  ...                                              ...
# 1310          Phone Call  Standard more film while question control wish.
# 1311         Online Chat       Join until window gas itself true control.
# 1312         Online Chat           Quality have nothing too argue public.
# 1313         Online Chat                 Actually over would general add.
# 1314          Phone Call                       Treat care eye democratic.
#
#           outcome  customer_id                  previous_interaction
# 0         Inquiry       874852  ef0a95e6-55b6-4363-887e-3f8fe17af252
# 1       Complaint       885532  abb348f6-4c79-44ba-ba7a-e02f829297b8
# 2     Transaction       637752  e124da1e-ed00-43d8-94c7-0c449e4f0760
# 3         Inquiry       542987  24e50ed1-2777-4444-95a1-6a92985ed445
# 4         Inquiry       984980  d01e933e-3da2-4f5d-b362-4a24081031bf
# ...           ...          ...                                   ...
# 1310      Inquiry       574567  7861d44c-e09e-453d-8a98-600c462ec24f
# 1311  Transaction       972751  7bf6f1bc-8a51-44b2-a998-34a12e9dd530
# 1312      Inquiry       494743  3ad4416c-d1b2-4796-87c4-65913ad57c39
# 1313    Complaint       489580  f6d3b525-1833-4005-9ecf-36cd4025dc17
# 1314    Complaint       794248  eed56db6-4a98-4f8c-8942-3d76f087869a
#
# [1315 rows x 7 columns]

# %%
df=interaction_level2[interaction_level2['outcome']=='Inquiry']
df.reset_index(drop=True,inplace=True)
#merged_data = pd.merge(product_data, df, on='interaction_id', how='inner')
interaction_level3=pd.DataFrame({
    "interaction_id": [fake.uuid4() for _ in range(len(df))],
    "timestamp": [fake.date_time_this_decade()  for _ in range(len(df))],
    "type_of_interaction": [random.choice(["Phone Call", "Branch Visit", "Online Chat"])  for _ in range(len(df))],
    "interaction_details": [fake.sentence()  for _ in range(len(df))],
    "outcome": [random.choice(["Inquiry", "Transaction" ])  for _ in range(len(df))],
    "customer_id":[df.loc[i,'customer_id'] for i in range(len(df))],
     "previous_interaction":[df.loc[i,'interaction_id'] for i in range(len(df))]
})



interaction_level3.to_csv('Data_new/interaction_level3.csv',index=False)

# %%
interaction_level3
# Out:
#                            interaction_id           timestamp  \
# 0    aca9aad1-56d5-4bd9-9bc5-ab7a8933798f 2021-09-10 07:36:35
# 1    6f951c25-acfe-4e69-a61c-7c8f4b902a8e 2021-07-19 02:57:24
# 2    68c5434d-ad7e-4150-9eb5-3abb26ada6ed 2021-12-27 15:01:22
# 3    5705064a-4d65-4383-a084-00054b5d1267 2024-01-19 18:37:16
# 4    6f0074ae-609e-4795-8a29-70b03f56b0b8 2021-02-01 07:45:00
# ..                                    ...                 ...
# 436  7a1ad1e5-9c72-47a4-b587-74b912af1b1a 2024-03-21 14:24:37
# 437  9c0c9698-7f49-442b-9465-99e83b21332c 2023-03-30 06:22:26
# 438  22fcffda-f683-44d5-bd00-bac1f8a4f304 2021-11-28 18:00:28
# 439  cf55999f-759f-4b42-b427-9e214c5637b7 2022-04-29 13:54:43
# 440  e0235473-aa25-4d09-bb90-2c6ea7f51254 2022-10-26 02:02:55
#
#     type_of_interaction                          interaction_details  \
# 0           Online Chat                       While heavy want grow.
# 1           Online Chat            West economic statement response.
# 2            Phone Call               Site dark rock sea child must.
# 3          Branch Visit      Tonight meet cut guess reach lose just.
# 4            Phone Call       Good general management coach concern.
# ..                  ...                                          ...
# 436          Phone Call    Yet machine growth community door always.
# 437          Phone Call    Stock affect experience structure arrive.
# 438          Phone Call  Look trade wonder recent information stand.
# 439          Phone Call      Ground side suggest morning first yard.
# 440        Branch Visit  Whatever only certain bring without minute.
#
#          outcome  customer_id                  previous_interaction
# 0        Inquiry       874852  c7c25ca1-3334-4980-9385-51b1761af7a0
# 1    Transaction       542987  0987d6b2-b32e-418e-b6d2-03785929d393
# 2    Transaction       984980  d29fc9ed-6a33-44df-8d39-3c0345573dd0
# 3        Inquiry       286396  b502a8af-a44d-452c-a752-d0c0e78f3ea9
# 4    Transaction       278171  4313966f-0d94-4ffb-863f-7e5647c2793c
# ..           ...          ...                                   ...
# 436  Transaction       983646  af5504a8-3f45-4313-922a-b6422109a44e
# 437  Transaction       645513  5a74c2b0-6f84-4eed-8f2c-f7450e33b685
# 438  Transaction       147342  88bf06fa-1d09-49e3-8418-1c10a1cab480
# 439  Transaction       574567  adc0fdfe-8b31-476c-bc41-ddc951a009a2
# 440      Inquiry       494743  a94c405b-34bc-447d-bec0-538380c28302
#
# [441 rows x 7 columns]

# %%
df=interaction_level3[interaction_level3['outcome']=='Inquiry']
df.reset_index(drop=True,inplace=True)
#merged_data = pd.merge(product_data, df, on='interaction_id', how='inner')
interaction_level4=pd.DataFrame({
    "interaction_id": [fake.uuid4() for _ in range(len(df))],
    "timestamp": [fake.date_time_this_decade()  for _ in range(len(df))],
    "type_of_interaction": [random.choice(["Phone Call", "Branch Visit", "Online Chat"])  for _ in range(len(df))],
    "interaction_details": [fake.sentence()  for _ in range(len(df))],
    "outcome": [random.choice(["Transaction" ])  for _ in range(len(df))],
    "customer_id":[df.loc[i,'customer_id'] for i in range(len(df))],
     "previous_interaction":[df.loc[i,'interaction_id'] for i in range(len(df))],
    
})

interaction_level4.to_csv('Data_new/interaction_level4.csv',index=False)

# %%
interaction_level4
# Out:
#                            interaction_id           timestamp  \
# 0    2a99d792-318b-4fcb-a484-15479ff054a7 2023-11-03 00:20:17
# 1    900b527a-eefa-46f5-b4a8-6aa3f63b43c8 2023-10-27 01:17:11
# 2    63c9f7fc-8ccc-46cb-991f-a821e29ae68e 2023-11-22 09:06:53
# 3    f8072b22-8aa9-48ef-9968-7a28405d665e 2020-03-06 15:19:11
# 4    d061d624-ac14-4ef5-a875-c1aea9ccd159 2020-07-18 19:10:45
# ..                                    ...                 ...
# 208  d256a232-40c0-4794-80ed-74df30c5a0fb 2023-12-04 23:58:53
# 209  e404245e-34f7-41a4-a878-34d652ff2ae0 2021-04-21 22:20:44
# 210  f7ae2681-b5b0-4418-af82-b008190e893c 2022-07-24 21:57:24
# 211  89d93a5d-8fb4-4443-924e-4ebbd5d9f448 2022-03-10 10:45:09
# 212  b53ae5cf-ef56-4a90-acc0-ca61f7efa2ca 2022-04-03 03:38:59
#
#     type_of_interaction                                interaction_details  \
# 0          Branch Visit                 Probably exactly tend dream night.
# 1          Branch Visit                    Focus back seem garden already.
# 2            Phone Call           Congress could within degree later pull.
# 3          Branch Visit                             Over white part prove.
# 4            Phone Call                    Huge box opportunity help able.
# ..                  ...                                                ...
# 208         Online Chat        Debate north drop movie late wrong popular.
# 209         Online Chat                          Song situation old score.
# 210         Online Chat  Keep then could maybe stock street important man.
# 211         Online Chat                         Lead girl film from stand.
# 212          Phone Call          Modern close little event window billion.
#
#          outcome  customer_id                  previous_interaction
# 0    Transaction       874852  aca9aad1-56d5-4bd9-9bc5-ab7a8933798f
# 1    Transaction       286396  5705064a-4d65-4383-a084-00054b5d1267
# 2    Transaction       432126  907e4dc9-7554-4b4c-ba89-8b183d5d8df5
# 3    Transaction       900555  8ca8a253-f264-4bf6-b35a-0ae785a23d8e
# 4    Transaction       238440  f28be5a1-fa2d-45ee-bc5f-a25a5614c93b
# ..           ...          ...                                   ...
# 208  Transaction       556350  fafd892b-6f24-4b53-ac66-8f99c9dc174c
# 209  Transaction       455953  18b4139a-b05f-47f4-a5fa-bb82652fc766
# 210  Transaction       407384  d1b8b89e-c433-4f27-93b8-7a4fcb80f4bb
# 211  Transaction       221877  b4a0b4a8-1887-4f4b-9ac7-af188a04b91f
# 212  Transaction       494743  e0235473-aa25-4d09-bb90-2c6ea7f51254
#
# [213 rows x 7 columns]

# %%
all_interaction=pd.concat([interaction,interaction_level2,interaction_level3,interaction_level4],join='inner',ignore_index=True)
all_interaction.to_csv('Data_new/all_interaction.csv',index=False)

# %%
branch_call = pd.DataFrame({
    "call_id": [fake.uuid4() for _ in range(interaction_level2.shape[0])],
    "timestamp": [fake.date_time_this_decade() for _ in range(interaction_level2.shape[0])],
    "caller": [random.choice(["Customer", "Bank Representative"]) for _ in range(interaction_level2.shape[0])],
    "purpose": [fake.sentence() for _ in range(interaction_level2.shape[0])],
    "product_discussed": [fake.word() for _ in range(interaction_level2.shape[0])],
    "outcome": [random.choice(["Inquiry Handled", "Follow-up Required"]) for _ in range(interaction_level2.shape[0])]
})
merge_data=pd.merge(product_data,interaction_level2,how='inner',on='customer_id')
branch_call['product_id']=merge_data.product_id
branch_call['interaction_id']=interaction_level2.interaction_id
branch_call.to_csv('Data_new/branch_call.csv',index=False)

# %%
branch_call
# Out:
#                                    call_id           timestamp  \
# 0     3d30d887-2bf1-4dc5-9288-38412e8f0fa0 2021-09-03 23:23:48
# 1     c8713304-1c29-482b-986a-714ec1f6485a 2022-10-07 07:52:19
# 2     b0165a3b-c6eb-4ed4-bf99-a35acdab4c28 2022-05-18 09:55:33
# 3     5d5d2499-697f-401e-92ae-79623e438f9f 2024-03-19 23:25:08
# 4     7a6590de-a477-47c0-a937-cae863cefb39 2020-07-06 14:24:00
# ...                                    ...                 ...
# 1310  da793d81-e78b-4ca3-a727-46b7904253c1 2022-01-07 01:13:32
# 1311  1810fab1-7001-48e1-a6ca-ac08aa8faa0e 2022-12-22 14:32:11
# 1312  9768ab16-c56c-48c3-91c6-f9fc7eb4f110 2024-04-18 08:56:27
# 1313  74ea27a4-b02b-46a0-a188-aaef0756dfa8 2022-02-08 11:01:16
# 1314  a94c0b13-2be1-4b1e-8175-77143a891133 2023-11-11 17:31:40
#
#                    caller                                            purpose  \
# 0     Bank Representative   Field consumer side skill magazine finally fear.
# 1     Bank Representative            In issue edge general rather candidate.
# 2     Bank Representative                        Until usually fact involve.
# 3     Bank Representative             Music must effect professor find just.
# 4                Customer     Could too various none street chair president.
# ...                   ...                                                ...
# 1310             Customer  Trouble clearly who along organization positiv...
# 1311  Bank Representative     Else seat sense blood soon color western stay.
# 1312  Bank Representative                      Truth test manager page ever.
# 1313             Customer                                   Huge term check.
# 1314             Customer        Put second program old leader mean prevent.
#
#      product_discussed             outcome  product_id  \
# 0                ahead  Follow-up Required         520
# 1                  car  Follow-up Required         520
# 2                front  Follow-up Required         520
# 3            authority  Follow-up Required         605
# 4                 vote     Inquiry Handled         605
# ...                ...                 ...         ...
# 1310              most     Inquiry Handled         340
# 1311              such     Inquiry Handled         340
# 1312              term  Follow-up Required         340
# 1313               not  Follow-up Required         728
# 1314             table  Follow-up Required         728
#
#                             interaction_id
# 0     c7c25ca1-3334-4980-9385-51b1761af7a0
# 1     793e0053-4f4c-4a7f-b875-492856a08300
# 2     fdbbf69d-9f01-4285-b5f7-b031b4bbdcd0
# 3     0987d6b2-b32e-418e-b6d2-03785929d393
# 4     d29fc9ed-6a33-44df-8d39-3c0345573dd0
# ...                                    ...
# 1310  adc0fdfe-8b31-476c-bc41-ddc951a009a2
# 1311  4f061966-ef23-46da-90d3-33e13bac3fb1
# 1312  a94c405b-34bc-447d-bec0-538380c28302
# 1313  57e9891c-5434-4d5a-afb1-474d3f527343
# 1314  26c0193f-8566-48ed-915e-5f9c72bc0d88
#
# [1315 rows x 8 columns]

# %%
call_response=pd.DataFrame({"call_response_id": [fake.unique.random_number(digits=5,fix_len=True) for i in range(len(branch_call))] ,
        "timestamp": [fake.date_time_this_decade() for i in range(len(branch_call))],
        "response_type": [random.choice(["Positive", "Negative", "Neutral"]) for i in  range(len(branch_call))],
        } )

call_response['call_id']=branch_call.call_id
call_response.to_csv('Data_new/call_response.csv',index=False)

# %%
call_response
# Out:
#       call_response_id           timestamp response_type  \
# 0                54438 2022-01-09 14:48:39      Negative
# 1                16861 2023-02-02 09:42:06       Neutral
# 2                77602 2023-10-01 00:03:21      Positive
# 3                35784 2020-04-27 19:13:54      Positive
# 4                72608 2020-03-24 23:20:51      Positive
# ...                ...                 ...           ...
# 1310             49895 2022-10-24 00:04:06      Positive
# 1311             59683 2020-12-18 15:57:50      Negative
# 1312             77099 2021-05-22 05:21:30      Positive
# 1313             31813 2020-11-11 02:00:31      Negative
# 1314             44121 2021-06-16 02:35:02      Positive
#
#                                    call_id
# 0     3d30d887-2bf1-4dc5-9288-38412e8f0fa0
# 1     c8713304-1c29-482b-986a-714ec1f6485a
# 2     b0165a3b-c6eb-4ed4-bf99-a35acdab4c28
# 3     5d5d2499-697f-401e-92ae-79623e438f9f
# 4     7a6590de-a477-47c0-a937-cae863cefb39
# ...                                    ...
# 1310  da793d81-e78b-4ca3-a727-46b7904253c1
# 1311  1810fab1-7001-48e1-a6ca-ac08aa8faa0e
# 1312  9768ab16-c56c-48c3-91c6-f9fc7eb4f110
# 1313  74ea27a4-b02b-46a0-a188-aaef0756dfa8
# 1314  a94c0b13-2be1-4b1e-8175-77143a891133
#
# [1315 rows x 4 columns]

# %%
application = pd.DataFrame({
    "application_id": [fake.unique.random_number(digits=5,fix_len=True) if response_type == 'Positive' else None for response_type in call_response['response_type']],
    "timestamp": [fake.date_time_this_decade() for _ in range(len(call_response['response_type']))],
    "application_type": [random.choice(["Loan Application", "Credit Card Application"]) for _ in range(len(call_response['response_type']))],
    "approval_id": [fake.uuid4() for _ in range(len(call_response['response_type']))],
    "approval_status": [random.choice(["Approved", "Rejected", "Pending"]) for _ in range(len(call_response['response_type']))]
})

application.dropna(inplace=True)
application['call_respose_id']=call_response.call_response_id
application.to_csv('Data_new/application.csv',index=False)

# %%
application
# Out:
#       application_id           timestamp         application_type  \
# 2            79240.0 2021-10-23 08:44:02         Loan Application
# 3            39367.0 2021-04-03 16:55:06         Loan Application
# 4            48858.0 2021-02-25 03:50:44         Loan Application
# 7            89221.0 2024-03-16 04:18:37         Loan Application
# 12           34283.0 2023-04-19 23:13:24  Credit Card Application
# ...              ...                 ...                      ...
# 1302         66537.0 2021-07-01 10:31:57  Credit Card Application
# 1308         22184.0 2024-04-03 19:48:32         Loan Application
# 1310         58548.0 2021-10-30 20:26:57  Credit Card Application
# 1312         99823.0 2022-06-30 16:13:44  Credit Card Application
# 1314         77548.0 2020-11-21 09:42:44         Loan Application
#
#                                approval_id approval_status  call_respose_id
# 2     e070981a-35e7-44ad-a035-045d6c5e8832        Approved            77602
# 3     7b3c36aa-21e2-49f1-9a20-1fac5ddc4ba1         Pending            35784
# 4     3d998c1d-e17a-437f-9d5a-7e4a9ec3af9b         Pending            72608
# 7     3caf669a-b57c-4e64-8aee-60165f97f21c         Pending            38233
# 12    4a60dc28-3866-4970-ad9f-dbc70c305b23         Pending            55633
# ...                                    ...             ...              ...
# 1302  7cc7753c-ea0c-44f8-9349-523ee6bfa7bc        Rejected            34581
# 1308  1abe0da2-6e12-44d4-95f3-b9ea2f2b04fe         Pending            44669
# 1310  2deb36bf-2494-459c-8039-4a3cf3b4007a         Pending            49895
# 1312  78138334-8e2b-4685-b685-6854952254ed         Pending            77099
# 1314  f6b3a433-25c6-43e4-8369-8a73fe275499         Pending            44121
#
# [430 rows x 6 columns]

# %%
approved_applications = application[application['approval_status'] == 'Approved']
l = len(approved_applications)

book = pd.DataFrame({
    "booking_id": [fake.unique.random_number(digits=6, fix_len=True) if status == 'Approved' else None for status in approved_applications['approval_status']],
    "booked_product": [fake.word() for _ in range(l)],
    "booking_details": [fake.sentence() for _ in range(l)],
    "approval_id": approved_applications['approval_id']
})

book.to_csv('Data_new/book.csv',index=False)

# %%
book
# Out:
#       booking_id booked_product  \
# 2         158660           many
# 14        610271          might
# 15        539327          party
# 25        553355           none
# 27        197532          movie
# ...          ...            ...
# 1286      269107      difficult
# 1293      749050           seek
# 1294      537775           sell
# 1297      569442          carry
# 1301      552529            who
#
#                                       booking_details  \
# 2                                      Good deal nor.
# 14              Vote relationship reach step control.
# 15                    Again each speech black number.
# 25                    Memory view language their day.
# 27                       Yourself lose keep big well.
# ...                                               ...
# 1286                         His employee north wall.
# 1293                                 Decade nor true.
# 1294  Usually serve magazine already total interview.
# 1297                                  Expert key low.
# 1301             Story nor article within about film.
#
#                                approval_id
# 2     e070981a-35e7-44ad-a035-045d6c5e8832
# 14    2b268dbd-aa3f-478e-9782-608e0596335c
# 15    d357879f-3aa0-4309-abbe-4fb234330025
# 25    1c443815-667e-4067-895f-0bf3b969ce1b
# 27    2bedca5f-08f8-4b6b-b860-daca4d172fc6
# ...                                    ...
# 1286  564c6009-5593-4271-946a-55caef529900
# 1293  ebce4179-b1a2-4f71-80c5-6eab791e472b
# 1294  5695e572-73b7-4285-b50a-65b0b12286ba
# 1297  e65eeb0f-d937-411a-b830-60140f2db619
# 1301  8f7d19aa-637d-4cc5-b2a9-f0f3e58ebd07
#
# [144 rows x 4 columns]
